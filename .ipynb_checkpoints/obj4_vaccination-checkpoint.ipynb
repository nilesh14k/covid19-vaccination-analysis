# %% [markdown]
# # Objective_4: NILESH KUMAR
# #### author: github.com/nilesh14k

# %% [markdown]
# ## Daily vaccination

# %%
import pandas as pd

daily_vac_df=pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations-by-manufacturer.csv')
daily_vac_df["date"] = pd.to_datetime(daily_vac_df["date"])
daily_vac_df
# Out:
#              location       date             vaccine  total_vaccinations
# 0           Argentina 2020-12-29  Oxford/AstraZeneca                   1
# 1           Argentina 2020-12-29   Sinopharm/Beijing                   1
# 2           Argentina 2020-12-29           Sputnik V               20489
# 3           Argentina 2020-12-30           Sputnik V               40591
# 4           Argentina 2020-12-31           Sputnik V               43397
# ...               ...        ...                 ...                 ...
# 50032  European Union 2022-11-18     Pfizer/BioNTech           653799859
# 50033  European Union 2022-11-18   Sinopharm/Beijing             2318499
# 50034  European Union 2022-11-18             Sinovac                7449
# 50035  European Union 2022-11-18           Sputnik V             1845376
# 50036  European Union 2022-11-18             Valneva                5217
#
# [50037 rows x 4 columns]

# %% [markdown]
# ### Calculating total number of vaccine for a particular vaccine type
# #### by individaul month

# %%
# daily_vac_df

from datetime import datetime

# function for finding last day of month
def last_day_of_month(year, month):
    """ Work out the last day of the month """
    last_days = [31, 30, 29, 28, 27]
    for i in last_days:
        try:
            end = datetime(year, month, i)
        except ValueError:
            continue
        else:
            return end.date()
    return None


# print(last_day_of_month(2001, 2))

# list of vaccine used
vaccine_ls = daily_vac_df['vaccine'].unique().tolist()

# list of locations
location_ls = daily_vac_df['location'].unique().tolist()


# find max value of a Y-vaccine for X-location
ls = []
df = pd.DataFrame(columns=['location', 'date', 'vaccine', 'total_vaccinations'])
for i in location_ls:
    for j, row in daily_vac_df.iterrows():
        if row['location'] == i:
            for k in vaccine_ls:
                if row['vaccine'] == k:
                    full_date = str(row['date']).split('-')
                    year = full_date[0]
                    month = full_date[1]
                    date = last_day_of_month(int(year), int(month))
                    # find max value of vaccine
                    # for this row wee need vaccine quantity, we already have:
                    # vaccine name and location name
#                     ts == pd.Timestamp(date)' or 'ts.date() == date
                    if row['date'] == date:
                        data = [{'location': i, 'date': date, 'vaccine': k,
                                 'total_vaccinations': row['total_vaccinations']}]
                        df2 = pd.DataFrame(data)
                        df = df.append(df2)
                        df
df.to_csv('vc.csv')
df
# Out:
# C:\Users\Navneet Kumar\AppData\Local\Temp\ipykernel_22176\3076341192.py:43: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   if row['date'] == date:
# C:\Users\Navneet Kumar\AppData\Local\Temp\ipykernel_22176\3076341192.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
# C:\Users\Navneet Kumar\AppData\Local\Temp\ipykernel_22176\3076341192.py:43: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   if row['date'] == date:
# ...

# %%
dff=pd.DataFrame(columns=['date','Oxford/AstraZeneca',
 'Sinopharm/Beijing',
 'SputnikV',
 'Pfizer/BioNTech',
 'Moderna',
 'CanSino',
 'Johnson&Johnson',
 'Novavax',
 'Valneva',
 'Medicago',
 'Sinovac',
 'Covaxin',
 'SKYCovione'])



dff
# Out:
# Empty DataFrame
# Columns: [date, Oxford/AstraZeneca, Sinopharm/Beijing, SputnikV, Pfizer/BioNTech, Moderna, CanSino, Johnson&Johnson, Novavax, Valneva, Medicago, Sinovac, Covaxin, SKYCovione]
# Index: []

# %% [markdown]
# ### converting YYYY-MM-DD to YY-MM

# %%
# daily_vac_df.date = pd.to_datetime(covid_daily_df.date).dt.to_period('m') #changing format
daily_vac_df

# %% [markdown]
# ## Daily COVID19

# %% [markdown]
# ### importing file

# %%
covid_daily_df=pd.read_csv('data/covid_daily_data.csv')
covid_daily_df["Date_reported"] = pd.to_datetime(covid_daily_df["Date_reported"])
covid_daily_df

# for i in range(1,100000000000)
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 248608    2022-11-12           ZW     Zimbabwe       AFRO          0
# 248609    2022-11-13           ZW     Zimbabwe       AFRO          0
# 248610    2022-11-14           ZW     Zimbabwe       AFRO          0
# 248611    2022-11-15           ZW     Zimbabwe       AFRO          0
# 248612    2022-11-16           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %% [markdown]
# ### converting YYYY-MM-DD to YY-MM

# %%
# covid_daily_df.Date_reported = pd.to_datetime(covid_daily_df.Date_reported).dt.to_period('m') #changing format
covid_daily_df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0            2020-01           AF  Afghanistan       EMRO          0
# 1            2020-01           AF  Afghanistan       EMRO          0
# 2            2020-01           AF  Afghanistan       EMRO          0
# 3            2020-01           AF  Afghanistan       EMRO          0
# 4            2020-01           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 248608       2022-11           ZW     Zimbabwe       AFRO          0
# 248609       2022-11           ZW     Zimbabwe       AFRO          0
# 248610       2022-11           ZW     Zimbabwe       AFRO          0
# 248611       2022-11           ZW     Zimbabwe       AFRO          0
# 248612       2022-11           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
# covid_daily_df.set_index('Date_reported', inplace=True)
# covid_daily_df.index = pd.to_datetime(covid_daily_df.index)
# covid_daily_df.resample('1M').mean()
# covid_daily_df

# %%
# daily_vac_df['date'] = pd.to_datetime(daily_vac_df['date']).dt.to_period('m')
# daily_vac_df.set_index('date', inplace=True)
# daily_vac_df.resample('1M').mean()
# # daily_vac_df

# %%
# import seaborn as sns

# ax=sns.lineplot(x=covid_daily_df.index,y="New_cases",data=covid_daily_df)
# ax.tick_params(axis='x', rotation=90)
# ax

# %%
# # sns.set()
# covid_daily_df
# # covid_daily_df.groupby('Country').sum().T.plot(kind='bar', stacked=True)

# %%
# # covid_df=pd.read_csv('data/covid_data.csv')
# # x=covid_df['Cases - cumulative total per 100000 population']/1000 #per 100
# # plt.xticks(rotation='vertical')
# # x.plot()
# # print(x)

# vac_df=pd.read_csv('data/vaccination_data.csv')
# y=pd.DataFrame(vac_df['PERSONS_FULLY_VACCINATED_PER100'])
# daily_vac_df.plot()
# # print(y)

# %%
# import matplotlib.pyplot as plt

# # # creating a DataFrame with 2 columns
# # dataFrame = pd.DataFrame(
# #    {
# #       "Car": ['BMW', 'Lexus', 'Audi', 'Mustang', 'Bentley', 'Jaguar'],"Reg_Price": [2000, 2500, 2800, 3000, 3200, 3500],"Units": [100, 120, 150, 170, 180, 200]
# #    }
# # )
# # plot a line graph
# plt.plot(y["Reg_Price"], dataFrame["Units"])
# plt.show()
